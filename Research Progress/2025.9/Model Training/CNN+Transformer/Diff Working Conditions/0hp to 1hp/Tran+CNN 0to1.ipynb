# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置（0hp用于训练/验证，1hp用于测试）
# ===============================
file_paths_0hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]
file_paths_1hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_1.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_1.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_1.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_1.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_1.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_1.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_1.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_1.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_1.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_1.mat"                     # Normal
]
labels = list(range(10))

segment_length = 256
test_size = 0.2       # 只用于 0hp 内部 train/val 划分之前的 train/test？——这次不用它来切 1hp
val_size  = 0.2       # 从 0hp 的训练部分再划验证
overlap   = 0.0

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer\Diff Working Conditions\0hp to 1hp"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train_0to1.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train_0to1.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val_0to1.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val_0to1.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test_0to1.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test_0to1.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
# ===============================
# 2. 生成数据（0hp -> 供 train/val；1hp -> 供 test）
# ===============================
    X0, y0 = load_and_segment_data(file_paths_0hp, labels, segment_length, overlap)  # 源域
    X1, y1 = load_and_segment_data(file_paths_1hp, labels, segment_length, overlap)  # 目标域（仅测试）
    
    # 0hp 内部分：先划出临时train_full/val临时（保持你的习惯，也可直接 train/val）
    X_train_full, X_val, y_train_full, y_val = train_test_split(
        X0, y0, test_size=val_size, stratify=y0, random_state=42
    )
    
    # 归一化：**只用 0hp 的训练统计量**（避免泄露目标域信息）
    mean, std = np.mean(X_train_full), np.std(X_train_full)
    X_train = ((X_train_full - mean) / std)[..., np.newaxis]
    X_val   = ((X_val       - mean) / std)[..., np.newaxis]
    X_test  = ((X1          - mean) / std)[..., np.newaxis]   # 注意：1hp 仅用 0hp 的均值方差做标准化
    
    y_train = y_train_full
    y_test  = y1

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train_0to1.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train_0to1.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val_0to1.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val_0to1.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test_0to1.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test_0to1.npy"), y_test)


print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape,   y_val.shape)
print("跨工况测试集大小(1hp):", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    # 多头注意力
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    # 前馈网络
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # CNN 提取局部特征
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    # Transformer 层
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)

    # 分类头
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ⚙️ 重新从 .mat 文件生成数据
# 训练集大小: (4188, 256, 1) (4188,)
# 验证集大小: (1047, 256, 1) (1047,)
# 跨工况测试集大小(1hp): (6172, 256, 1) (6172,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 256, 32)           │             256 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d (MaxPooling1D)  │ (None, 128, 32)           │               0 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_1               │ (None, 64, 64)            │               0 │ conv1d_1[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 64, 64)            │             128 │ max_pooling1d_1[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 64, 64)            │          16,640 │ layer_normalization[0][0], │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 64, 64)            │               0 │ max_pooling1d_1[0][0],     │
# │                               │                           │                 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 64, 64)            │             128 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64, 64)            │           4,160 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64, 64)            │           4,160 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 64, 64)            │               0 │ add[0][0], dense_1[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 64, 64)            │             128 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 64, 64)            │          16,640 │ layer_normalization_2[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 64, 64)            │               0 │ add_1[0][0],               │
# │                               │                           │                 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 64, 64)            │             128 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 64, 64)            │               0 │ add_2[0][0], dense_3[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 64)                │               0 │ add_3[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 10)                │             650 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.4297 - loss: 1.7547 - val_accuracy: 0.9303 - val_loss: 0.2567 - learning_rate: 0.0010
# Epoch 2/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9291 - loss: 0.2301 - val_accuracy: 0.9589 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 3/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9530 - loss: 0.1336 - val_accuracy: 0.9771 - val_loss: 0.0656 - learning_rate: 0.0010
# Epoch 4/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9718 - loss: 0.0892 - val_accuracy: 0.9723 - val_loss: 0.0815 - learning_rate: 0.0010
# Epoch 5/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9772 - loss: 0.0678 - val_accuracy: 0.9713 - val_loss: 0.0811 - learning_rate: 0.0010
# Epoch 6/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9754 - loss: 0.0793 - val_accuracy: 0.9838 - val_loss: 0.0548 - learning_rate: 0.0010
# Epoch 7/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9853 - loss: 0.0411 - val_accuracy: 0.9904 - val_loss: 0.0205 - learning_rate: 0.0010
# Epoch 8/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9854 - loss: 0.0417 - val_accuracy: 0.9828 - val_loss: 0.0403 - learning_rate: 0.0010
# Epoch 9/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9941 - loss: 0.0198 - val_accuracy: 0.9895 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 10/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9927 - loss: 0.0219 - val_accuracy: 0.9895 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 11/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9882 - loss: 0.0354 - val_accuracy: 0.9742 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 12/30
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9809 - loss: 0.0504
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9811 - loss: 0.0499 - val_accuracy: 0.9838 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 13/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9884 - loss: 0.0349 - val_accuracy: 0.9952 - val_loss: 0.0160 - learning_rate: 5.0000e-04
# Epoch 14/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9966 - loss: 0.0122 - val_accuracy: 0.9933 - val_loss: 0.0170 - learning_rate: 5.0000e-04
# Epoch 15/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9971 - loss: 0.0095 - val_accuracy: 0.9943 - val_loss: 0.0135 - learning_rate: 5.0000e-04
# Epoch 16/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9983 - loss: 0.0077 - val_accuracy: 0.9990 - val_loss: 0.0083 - learning_rate: 5.0000e-04
# Epoch 17/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 0.9962 - val_loss: 0.0117 - learning_rate: 5.0000e-04
# Epoch 18/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9998 - loss: 0.0023 - val_accuracy: 0.9971 - val_loss: 0.0102 - learning_rate: 5.0000e-04
# Epoch 19/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9971 - val_loss: 0.0084 - learning_rate: 5.0000e-04
# Epoch 20/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9962 - val_loss: 0.0113 - learning_rate: 5.0000e-04
# Epoch 21/30
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9997 - loss: 0.0015
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9952 - val_loss: 0.0167 - learning_rate: 5.0000e-04
# Epoch 22/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9990 - loss: 0.0039 - val_accuracy: 0.9962 - val_loss: 0.0121 - learning_rate: 2.5000e-04
# Epoch 23/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9962 - val_loss: 0.0066 - learning_rate: 2.5000e-04
# Epoch 24/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 7.8269e-04 - val_accuracy: 0.9971 - val_loss: 0.0076 - learning_rate: 2.5000e-04
# Epoch 25/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 1.0000 - loss: 6.6268e-04 - val_accuracy: 0.9981 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 26/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 8.7660e-04 - val_accuracy: 0.9962 - val_loss: 0.0063 - learning_rate: 2.5000e-04
# Epoch 27/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 9.7427e-04 - val_accuracy: 0.9962 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 28/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 5.3864e-04 - val_accuracy: 0.9962 - val_loss: 0.0078 - learning_rate: 2.5000e-04
# Epoch 29/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 1.0000 - loss: 5.4909e-04 - val_accuracy: 0.9971 - val_loss: 0.0074 - learning_rate: 2.5000e-04
# Epoch 30/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 1.0000 - loss: 4.9173e-04 - val_accuracy: 0.9962 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 26.
# 测试集准确率: 0.8683
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
#               precision    recall  f1-score   support
#
#         B007       0.85      0.76      0.80       474
#         B014       0.72      1.00      0.84       477
#         B021       0.80      0.67      0.73       475
#        IR007       0.99      1.00      0.99       476
#        IR014       0.00      0.00      0.00       475
#        IR021       1.00      0.98      0.99       474
#        OR007       0.99      0.89      0.94       478
#        OR014       0.71      1.00      0.83       477
#        OR021       0.63      0.99      0.77       476
#       Normal       1.00      1.00      1.00      1890
#
#     accuracy                           0.87      6172
#    macro avg       0.77      0.83      0.79      6172
# weighted avg       0.82      0.87      0.84      6172
# D:\study\anaconda\envs\tf2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\study\anaconda\envs\tf2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\study\anaconda\envs\tf2\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
