# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置（2hp用于训练/验证，3hp用于测试）
# ===============================
file_paths_2hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_2.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_2.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_2.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_2.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_2.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_2.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_2.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_2.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_2.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_2.mat" 
]
file_paths_3hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_3.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_3.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_3.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_3.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_3.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_3.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_3.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_3.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_3.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_3.mat" 
]
labels = list(range(10))

segment_length = 256
val_size  = 0.2       # 从 0hp 的训练部分再划验证
overlap   = 0.0

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer\Diff Working Conditions\2hp to 3hp"
save_files = [os.path.join(save_dir, f) for f in [
    "X_train_0to3.npy","y_train_0to3.npy",
    "X_val_0to3.npy","y_val_0to3.npy",
    "X_test_0to3.npy","y_test_0to3.npy"
]]

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(save_files[0]); y_train = np.load(save_files[1])
    X_val   = np.load(save_files[2]); y_val   = np.load(save_files[3])
    X_test  = np.load(save_files[4]); y_test  = np.load(save_files[5])
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    # 2hp -> train/val
    X2, y2 = load_and_segment_data(file_paths_2hp, labels, segment_length, overlap)
    # 3hp -> test
    X3, y3 = load_and_segment_data(file_paths_3hp, labels, segment_length, overlap)
    
    # 2hp 内部分：划分训练/验证
    X_train_full, X_val, y_train_full, y_val = train_test_split(
        X2, y2, test_size=val_size, stratify=y2, random_state=42
    )
    
    # 标准化（只用 2hp 训练集统计量）
    mean, std = np.mean(X_train_full), np.std(X_train_full)
    X_train = ((X_train_full - mean) / std)[..., np.newaxis]
    X_val   = ((X_val       - mean) / std)[..., np.newaxis]
    X_test  = ((X3          - mean) / std)[..., np.newaxis]
    
    y_train = y_train_full
    y_test  = y3

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(save_files[0], X_train); np.save(save_files[1], y_train)
    np.save(save_files[2], X_val);   np.save(save_files[3], y_val)
    np.save(save_files[4], X_test);  np.save(save_files[5], y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape,   y_val.shape)
print("跨工况测试集大小(3hp):", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"跨工况测试集(3hp)准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ⚙️ 重新从 .mat 文件生成数据
# 训练集大小: (4936, 256, 1) (4936,)
# 验证集大小: (1234, 256, 1) (1234,)
# 跨工况测试集大小(3hp): (6186, 256, 1) (6186,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 256, 32)           │             256 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d (MaxPooling1D)  │ (None, 128, 32)           │               0 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_1               │ (None, 64, 64)            │               0 │ conv1d_1[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 64, 64)            │             128 │ max_pooling1d_1[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 64, 64)            │          16,640 │ layer_normalization[0][0], │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 64, 64)            │               0 │ max_pooling1d_1[0][0],     │
# │                               │                           │                 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 64, 64)            │             128 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64, 64)            │           4,160 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64, 64)            │           4,160 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 64, 64)            │               0 │ add[0][0], dense_1[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 64, 64)            │             128 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 64, 64)            │          16,640 │ layer_normalization_2[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 64, 64)            │               0 │ add_1[0][0],               │
# │                               │                           │                 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 64, 64)            │             128 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 64, 64)            │               0 │ add_2[0][0], dense_3[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 64)                │               0 │ add_3[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 10)                │             650 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.5499 - loss: 1.3316 - val_accuracy: 0.7909 - val_loss: 0.7356 - learning_rate: 0.0010
# Epoch 2/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.8993 - loss: 0.2870 - val_accuracy: 0.9765 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 3/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9613 - loss: 0.1091 - val_accuracy: 0.9449 - val_loss: 0.1524 - learning_rate: 0.0010
# Epoch 4/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9638 - loss: 0.1033 - val_accuracy: 0.9765 - val_loss: 0.0685 - learning_rate: 0.0010
# Epoch 5/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9881 - loss: 0.0365 - val_accuracy: 0.9797 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 6/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9869 - loss: 0.0454 - val_accuracy: 0.9830 - val_loss: 0.0539 - learning_rate: 0.0010
# Epoch 7/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9748 - loss: 0.0776 - val_accuracy: 0.9676 - val_loss: 0.1029 - learning_rate: 0.0010
# Epoch 8/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9877 - loss: 0.0322 - val_accuracy: 0.9959 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 9/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9945 - loss: 0.0152 - val_accuracy: 0.9951 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 10/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9899 - loss: 0.0284 - val_accuracy: 0.9943 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 11/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9942 - loss: 0.0178 - val_accuracy: 0.9984 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 12/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9943 - val_loss: 0.0209 - learning_rate: 0.0010
# Epoch 13/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9984 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 14/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9992 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 15/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9773 - val_loss: 0.0909 - learning_rate: 0.0010
# Epoch 16/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9896 - loss: 0.0312 - val_accuracy: 0.9903 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 17/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.9936 - loss: 0.0221 - val_accuracy: 0.9911 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 18/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.9976 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 19/30
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 5.3185e-04
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 1.0000 - loss: 5.3386e-04 - val_accuracy: 0.9951 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 20/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9992 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 21/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 1.0000 - loss: 1.7531e-04 - val_accuracy: 0.9976 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 22/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 1.0000 - loss: 2.2744e-04 - val_accuracy: 0.9992 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 23/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 1.4033e-04 - val_accuracy: 0.9976 - val_loss: 0.0025 - learning_rate: 5.0000e-04
# Epoch 24/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 1.0000 - loss: 1.4401e-04 - val_accuracy: 0.9984 - val_loss: 0.0037 - learning_rate: 5.0000e-04
# Epoch 25/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 1.3200e-04 - val_accuracy: 0.9984 - val_loss: 0.0044 - learning_rate: 5.0000e-04
# Epoch 26/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 1.0000 - loss: 1.1904e-04 - val_accuracy: 0.9976 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 27/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 1.0000 - loss: 1.4149e-04 - val_accuracy: 0.9976 - val_loss: 0.0045 - learning_rate: 5.0000e-04
# Epoch 28/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.4006e-04
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 1.4014e-04 - val_accuracy: 0.9976 - val_loss: 0.0057 - learning_rate: 5.0000e-04
# Epoch 29/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 1.0000 - loss: 1.0609e-04 - val_accuracy: 0.9992 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 30/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 1.0000 - loss: 1.1786e-04 - val_accuracy: 0.9992 - val_loss: 0.0035 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 23.
# 跨工况测试集(3hp)准确率: 0.8923
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
#               precision    recall  f1-score   support
#
#         B007       1.00      0.87      0.93       474
#         B014       0.94      0.86      0.90       477
#         B021       0.98      0.77      0.86       477
#        IR007       0.48      1.00      0.65       480
#        IR014       0.52      0.11      0.19       475
#        IR021       1.00      1.00      1.00       476
#        OR007       1.00      1.00      1.00       478
#        OR014       1.00      0.99      1.00       476
#        OR021       0.99      1.00      0.99       476
#       Normal       0.97      1.00      0.99      1897
#
#     accuracy                           0.89      6186
#    macro avg       0.89      0.86      0.85      6186
# weighted avg       0.91      0.89      0.88      6186
