# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置
# ===============================
file_paths = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]

labels = list(range(10))  # 10个类别

segment_length = 256   # 每个样本长度
test_size = 0.2        # 训练/测试划分比例
val_size = 0.2         # 验证集划分比例（从训练集中再划）
overlap = 0.0          # 重叠率

# 保存目录（绝对路径，和 .ipynb 同目录）
save_dir = r"D:\study\code\Model Training\Transformer 1D"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 判断是否已有预处理数据
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    X, y = load_and_segment_data(file_paths, labels, segment_length, overlap)

    # 先划分 训练+临时 / 测试
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=42)
    # 再划分 训练 / 验证
    X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=val_size, stratify=y_train_full, random_state=42)

    # 归一化 & 扩展维度
    mean, std = np.mean(X_train), np.std(X_train)
    X_train = ((X_train - mean) / std)[..., np.newaxis]
    X_val   = ((X_val   - mean) / std)[..., np.newaxis]
    X_test  = ((X_test  - mean) / std)[..., np.newaxis]

    # 保存
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape, y_val.shape)
print("测试集大小:", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 Transfoemer 1D 模型
# ===============================
def build_transformer1d(input_shape, num_classes, num_heads=4, ff_dim=64, num_blocks=2):
    """
    input_shape: (segment_length, 1)
    num_classes: 分类数
    num_heads: Multi-Head Attention 的头数
    ff_dim: 前馈层的维度
    num_blocks: Transformer Block 堆叠的数量
    """
    inputs = layers.Input(shape=input_shape)

    # 线性映射到更高维度 (embedding)
    x = layers.Conv1D(64, kernel_size=1, padding="same")(inputs)

    # 位置编码（用正弦余弦函数，简化版）
    positions = tf.range(start=0, limit=input_shape[0], delta=1)
    pos_encoding = layers.Embedding(input_dim=input_shape[0], output_dim=64)(positions)
    x = x + pos_encoding

    # 堆叠 Transformer Block
    for _ in range(num_blocks):
        # 多头自注意力
        attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=64)(x, x)
        attn_output = layers.Dropout(0.1)(attn_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)

        # 前馈网络
        ff_output = layers.Dense(ff_dim, activation="relu")(x)
        ff_output = layers.Dense(64)(ff_output)
        ff_output = layers.Dropout(0.1)(ff_output)
        x = layers.LayerNormalization(epsilon=1e-6)(x + ff_output)

    # 全局池化 + 输出
    x = layers.GlobalAveragePooling1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_transformer1d(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ✅ 发现已有预处理数据，直接加载
# 训练集大小: (3350, 256, 1) (3350,)
# 验证集大小: (838, 256, 1) (838,)
# 测试集大小: (1047, 256, 1) (1047,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 256, 64)           │             128 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 256, 64)           │               0 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 256, 64)           │          66,368 │ add[0][0], add[0][0]       │
# │ (MultiHeadAttention)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 256, 64)           │               0 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 256, 64)           │               0 │ add[0][0], dropout_1[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 256, 64)           │             128 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 256, 64)           │           4,160 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 256, 64)           │           4,160 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 256, 64)           │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 256, 64)           │               0 │ layer_normalization[0][0], │
# │                               │                           │                 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 256, 64)           │             128 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 256, 64)           │          66,368 │ layer_normalization_1[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 256, 64)           │               0 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 256, 64)           │               0 │ layer_normalization_1[0][… │
# │                               │                           │                 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 256, 64)           │             128 │ add_3[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 256, 64)           │           4,160 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 256, 64)           │           4,160 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 256, 64)           │               0 │ dense_3[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 256, 64)           │               0 │ layer_normalization_2[0][… │
# │                               │                           │                 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 256, 64)           │             128 │ add_4[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 64)                │               0 │ layer_normalization_3[0][… │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 10)                │             650 │ global_average_pooling1d[… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 150,666 (588.54 KB)
#  Trainable params: 150,666 (588.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 23s 341ms/step - accuracy: 0.3545 - loss: 1.8070 - val_accuracy: 0.7315 - val_loss: 0.7969 - learning_rate: 0.0010
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 333ms/step - accuracy: 0.7471 - loss: 0.7088 - val_accuracy: 0.8246 - val_loss: 0.4730 - learning_rate: 0.0010
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 331ms/step - accuracy: 0.8173 - loss: 0.5230 - val_accuracy: 0.8461 - val_loss: 0.4353 - learning_rate: 0.0010
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - accuracy: 0.8408 - loss: 0.4509 - val_accuracy: 0.8532 - val_loss: 0.4067 - learning_rate: 0.0010
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 331ms/step - accuracy: 0.8407 - loss: 0.4267 - val_accuracy: 0.8532 - val_loss: 0.3892 - learning_rate: 0.0010
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 331ms/step - accuracy: 0.8313 - loss: 0.4558 - val_accuracy: 0.8663 - val_loss: 0.3427 - learning_rate: 0.0010
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 335ms/step - accuracy: 0.8440 - loss: 0.4301 - val_accuracy: 0.8640 - val_loss: 0.3512 - learning_rate: 0.0010
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 331ms/step - accuracy: 0.8674 - loss: 0.3848 - val_accuracy: 0.8616 - val_loss: 0.3696 - learning_rate: 0.0010
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 332ms/step - accuracy: 0.8573 - loss: 0.3845 - val_accuracy: 0.8496 - val_loss: 0.3963 - learning_rate: 0.0010
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 334ms/step - accuracy: 0.8475 - loss: 0.3797 - val_accuracy: 0.8878 - val_loss: 0.3045 - learning_rate: 0.0010
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - accuracy: 0.8820 - loss: 0.3562 - val_accuracy: 0.8663 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 20s 333ms/step - accuracy: 0.8472 - loss: 0.4021 - val_accuracy: 0.8640 - val_loss: 0.3761 - learning_rate: 0.0010
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 332ms/step - accuracy: 0.8634 - loss: 0.3701 - val_accuracy: 0.8890 - val_loss: 0.3068 - learning_rate: 0.0010
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 361ms/step - accuracy: 0.8624 - loss: 0.3554 - val_accuracy: 0.9045 - val_loss: 0.2663 - learning_rate: 0.0010
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 361ms/step - accuracy: 0.8864 - loss: 0.3087 - val_accuracy: 0.8854 - val_loss: 0.2974 - learning_rate: 0.0010
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 20s 369ms/step - accuracy: 0.8822 - loss: 0.3081 - val_accuracy: 0.8962 - val_loss: 0.2702 - learning_rate: 0.0010
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 361ms/step - accuracy: 0.8723 - loss: 0.3307 - val_accuracy: 0.8974 - val_loss: 0.2602 - learning_rate: 0.0010
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - accuracy: 0.8571 - loss: 0.3430 - val_accuracy: 0.9165 - val_loss: 0.2444 - learning_rate: 0.0010
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - accuracy: 0.8873 - loss: 0.3159 - val_accuracy: 0.8926 - val_loss: 0.2935 - learning_rate: 0.0010
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 341ms/step - accuracy: 0.8834 - loss: 0.3147 - val_accuracy: 0.9033 - val_loss: 0.2564 - learning_rate: 0.0010
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 343ms/step - accuracy: 0.8715 - loss: 0.3506 - val_accuracy: 0.8890 - val_loss: 0.2843 - learning_rate: 0.0010
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 339ms/step - accuracy: 0.8642 - loss: 0.3515 - val_accuracy: 0.9010 - val_loss: 0.2492 - learning_rate: 0.0010
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8861 - loss: 0.3084
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 343ms/step - accuracy: 0.8860 - loss: 0.3086 - val_accuracy: 0.9069 - val_loss: 0.2527 - learning_rate: 0.0010
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 21s 343ms/step - accuracy: 0.8993 - loss: 0.2633 - val_accuracy: 0.9105 - val_loss: 0.2463 - learning_rate: 5.0000e-04
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 20s 339ms/step - accuracy: 0.9038 - loss: 0.2636 - val_accuracy: 0.8938 - val_loss: 0.2571 - learning_rate: 5.0000e-04
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 350ms/step - accuracy: 0.8887 - loss: 0.2869 - val_accuracy: 0.9021 - val_loss: 0.2421 - learning_rate: 5.0000e-04
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 19s 348ms/step - accuracy: 0.8929 - loss: 0.2873 - val_accuracy: 0.9129 - val_loss: 0.2426 - learning_rate: 5.0000e-04
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 345ms/step - accuracy: 0.8867 - loss: 0.2920 - val_accuracy: 0.9117 - val_loss: 0.2300 - learning_rate: 5.0000e-04
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 343ms/step - accuracy: 0.8920 - loss: 0.2682 - val_accuracy: 0.8962 - val_loss: 0.2462 - learning_rate: 5.0000e-04
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 18s 348ms/step - accuracy: 0.9081 - loss: 0.2352 - val_accuracy: 0.8974 - val_loss: 0.2364 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 28.
# 测试集准确率: 0.8854
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step
#               precision    recall  f1-score   support
#
#         B007       0.86      0.94      0.90        96
#         B014       0.83      0.80      0.81        95
#         B021       0.75      0.80      0.78        95
#        IR007       0.90      0.99      0.94        95
#        IR014       0.99      0.75      0.85        95
#        IR021       0.93      0.89      0.91        95
#        OR007       0.94      0.97      0.95        95
#        OR014       0.78      0.78      0.78        95
#        OR021       0.90      0.85      0.88        96
#       Normal       0.94      0.98      0.96       190
#
#     accuracy                           0.89      1047
#    macro avg       0.88      0.88      0.88      1047
# weighted avg       0.89      0.89      0.88      1047
