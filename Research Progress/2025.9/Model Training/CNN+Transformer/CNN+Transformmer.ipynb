# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置
# ===============================
file_paths = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]

labels = list(range(10))  # 10个类别

segment_length = 256   # 每个样本长度
test_size = 0.2        # 训练/测试划分比例
val_size = 0.2         # 验证集划分比例
overlap = 0.0          # 重叠率

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    X, y = load_and_segment_data(file_paths, labels, segment_length, overlap)

    # 划分
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=val_size, stratify=y_train_full, random_state=42)

    # 归一化 & 扩展维度
    mean, std = np.mean(X_train), np.std(X_train)
    X_train = ((X_train - mean) / std)[..., np.newaxis]
    X_val   = ((X_val   - mean) / std)[..., np.newaxis]
    X_test  = ((X_test  - mean) / std)[..., np.newaxis]

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape, y_val.shape)
print("测试集大小:", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    # 多头注意力
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    # 前馈网络
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # CNN 提取局部特征
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    # Transformer 层
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)

    # 分类头
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ✅ 发现已有预处理数据，直接加载
# 训练集大小: (3350, 256, 1) (3350,)
# 验证集大小: (838, 256, 1) (838,)
# 测试集大小: (1047, 256, 1) (1047,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 256, 32)           │             256 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_2               │ (None, 128, 32)           │               0 │ conv1d_2[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_3               │ (None, 64, 64)            │               0 │ conv1d_3[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 64, 64)            │             128 │ max_pooling1d_3[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 64, 64)            │          16,640 │ layer_normalization_2[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 64, 64)            │               0 │ max_pooling1d_3[0][0],     │
# │                               │                           │                 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 64, 64)            │             128 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64, 64)            │           4,160 │ layer_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64, 64)            │           4,160 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 64, 64)            │               0 │ add_1[0][0], dense_1[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_4         │ (None, 64, 64)            │             128 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_2        │ (None, 64, 64)            │          16,640 │ layer_normalization_4[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 64, 64)            │               0 │ add_2[0][0],               │
# │                               │                           │                 │ multi_head_attention_2[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_5         │ (None, 64, 64)            │             128 │ add_3[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 64, 64)            │               0 │ add_3[0][0], dense_3[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 64)                │               0 │ add_4[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 10)                │             650 │ dropout_3[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.4360 - loss: 1.6612 - val_accuracy: 0.9081 - val_loss: 0.3242 - learning_rate: 0.0010
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8940 - loss: 0.3262 - val_accuracy: 0.9320 - val_loss: 0.2002 - learning_rate: 0.0010
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9489 - loss: 0.1536 - val_accuracy: 0.9547 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9701 - loss: 0.0907 - val_accuracy: 0.9845 - val_loss: 0.0479 - learning_rate: 0.0010
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9686 - loss: 0.0851 - val_accuracy: 0.9606 - val_loss: 0.1001 - learning_rate: 0.0010
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9675 - loss: 0.0947 - val_accuracy: 0.9821 - val_loss: 0.0550 - learning_rate: 0.0010
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9702 - loss: 0.0962 - val_accuracy: 0.9690 - val_loss: 0.0747 - learning_rate: 0.0010
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9736 - loss: 0.0773 - val_accuracy: 0.9260 - val_loss: 0.2448 - learning_rate: 0.0010
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9494 - loss: 0.1709 - val_accuracy: 0.9916 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9910 - loss: 0.0349 - val_accuracy: 0.9905 - val_loss: 0.0227 - learning_rate: 0.0010
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9931 - loss: 0.0229 - val_accuracy: 0.9952 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9931 - loss: 0.0213 - val_accuracy: 0.9928 - val_loss: 0.0279 - learning_rate: 0.0010
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9846 - loss: 0.0448 - val_accuracy: 0.9821 - val_loss: 0.0396 - learning_rate: 0.0010
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9877 - loss: 0.0356 - val_accuracy: 0.9833 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9877 - loss: 0.0326 - val_accuracy: 0.9976 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9971 - loss: 0.0114 - val_accuracy: 0.9869 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9739 - loss: 0.0793 - val_accuracy: 0.9809 - val_loss: 0.0859 - learning_rate: 0.0010
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9770 - loss: 0.0692 - val_accuracy: 0.9749 - val_loss: 0.0729 - learning_rate: 0.0010
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9784 - loss: 0.0614 - val_accuracy: 0.9976 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9981 - loss: 0.0073 - val_accuracy: 0.9988 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.9990 - loss: 0.0048 - val_accuracy: 0.9964 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9995 - loss: 0.0043 - val_accuracy: 0.9976 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9988 - loss: 0.0032 - val_accuracy: 0.9940 - val_loss: 0.0187 - learning_rate: 0.0010
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9977 - loss: 0.0058 - val_accuracy: 0.9988 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 25/30
# 51/53 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9964 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 8.9315e-04 - val_accuracy: 0.9976 - val_loss: 0.0050 - learning_rate: 5.0000e-04
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 1.0000 - loss: 3.9841e-04 - val_accuracy: 0.9988 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 1.0000 - loss: 3.6688e-04 - val_accuracy: 0.9988 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 1.0000 - loss: 3.9407e-04 - val_accuracy: 0.9976 - val_loss: 0.0054 - learning_rate: 5.0000e-04
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 1.0000 - loss: 3.5846e-04 - val_accuracy: 0.9988 - val_loss: 0.0053 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 27.
# 测试集准确率: 1.0000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
#               precision    recall  f1-score   support
#
#         B007       1.00      1.00      1.00        96
#         B014       1.00      1.00      1.00        95
#         B021       1.00      1.00      1.00        95
#        IR007       1.00      1.00      1.00        95
#        IR014       1.00      1.00      1.00        95
#        IR021       1.00      1.00      1.00        95
#        OR007       1.00      1.00      1.00        95
#        OR014       1.00      1.00      1.00        95
#        OR021       1.00      1.00      1.00        96
#       Normal       1.00      1.00      1.00       190
#
#     accuracy                           1.00      1047
#    macro avg       1.00      1.00      1.00      1047
# weighted avg       1.00      1.00      1.00      1047

# %% [markdown]
# # 起始学习率从1e-3降到1e-5

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置
# ===============================
file_paths = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]

labels = list(range(10))  # 10个类别

segment_length = 256   # 每个样本长度
test_size = 0.2        # 训练/测试划分比例
val_size = 0.2         # 验证集划分比例
overlap = 0.0          # 重叠率

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    X, y = load_and_segment_data(file_paths, labels, segment_length, overlap)

    # 划分
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=val_size, stratify=y_train_full, random_state=42)

    # 归一化 & 扩展维度
    mean, std = np.mean(X_train), np.std(X_train)
    X_train = ((X_train - mean) / std)[..., np.newaxis]
    X_val   = ((X_val   - mean) / std)[..., np.newaxis]
    X_test  = ((X_test  - mean) / std)[..., np.newaxis]

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape, y_val.shape)
print("测试集大小:", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    # 多头注意力
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    # 前馈网络
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # CNN 提取局部特征
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    # Transformer 层
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)

    # 分类头
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ✅ 发现已有预处理数据，直接加载
# 训练集大小: (3350, 256, 1) (3350,)
# 验证集大小: (838, 256, 1) (838,)
# 测试集大小: (1047, 256, 1) (1047,)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 256, 32)           │             256 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_4               │ (None, 128, 32)           │               0 │ conv1d_4[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_5 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_5               │ (None, 64, 64)            │               0 │ conv1d_5[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_6         │ (None, 64, 64)            │             128 │ max_pooling1d_5[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_3        │ (None, 64, 64)            │          16,640 │ layer_normalization_6[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 64, 64)            │               0 │ max_pooling1d_5[0][0],     │
# │                               │                           │                 │ multi_head_attention_3[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_7         │ (None, 64, 64)            │             128 │ add_5[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_6 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_5[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_6 (Add)                   │ (None, 64, 64)            │               0 │ add_5[0][0], dense_6[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_8         │ (None, 64, 64)            │             128 │ add_6[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_4        │ (None, 64, 64)            │          16,640 │ layer_normalization_8[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_7 (Add)                   │ (None, 64, 64)            │               0 │ add_6[0][0],               │
# │                               │                           │                 │ multi_head_attention_4[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_9         │ (None, 64, 64)            │             128 │ add_7[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_7 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_7[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_8 (Add)                   │ (None, 64, 64)            │               0 │ add_7[0][0], dense_8[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d_1    │ (None, 64)                │               0 │ add_8[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_6 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 10)                │             650 │ dropout_6[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.1156 - loss: 2.7474 - val_accuracy: 0.1862 - val_loss: 2.1733 - learning_rate: 1.0000e-05
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.1924 - loss: 2.2627 - val_accuracy: 0.3413 - val_loss: 1.9689 - learning_rate: 1.0000e-05
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2739 - loss: 2.0628 - val_accuracy: 0.4368 - val_loss: 1.8110 - learning_rate: 1.0000e-05
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3432 - loss: 1.9118 - val_accuracy: 0.5215 - val_loss: 1.6744 - learning_rate: 1.0000e-05
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4057 - loss: 1.7565 - val_accuracy: 0.5525 - val_loss: 1.5416 - learning_rate: 1.0000e-05
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4749 - loss: 1.5991 - val_accuracy: 0.5692 - val_loss: 1.4149 - learning_rate: 1.0000e-05
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5381 - loss: 1.4676 - val_accuracy: 0.6874 - val_loss: 1.2681 - learning_rate: 1.0000e-05
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6172 - loss: 1.3185 - val_accuracy: 0.7852 - val_loss: 1.1354 - learning_rate: 1.0000e-05
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6915 - loss: 1.1629 - val_accuracy: 0.8628 - val_loss: 1.0173 - learning_rate: 1.0000e-05
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7470 - loss: 1.0542 - val_accuracy: 0.9165 - val_loss: 0.9165 - learning_rate: 1.0000e-05
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7877 - loss: 0.9637 - val_accuracy: 0.9189 - val_loss: 0.8236 - learning_rate: 1.0000e-05
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8295 - loss: 0.8804 - val_accuracy: 0.9320 - val_loss: 0.7426 - learning_rate: 1.0000e-05
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8427 - loss: 0.8009 - val_accuracy: 0.9356 - val_loss: 0.6751 - learning_rate: 1.0000e-05
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8897 - loss: 0.7072 - val_accuracy: 0.9356 - val_loss: 0.6100 - learning_rate: 1.0000e-05
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8830 - loss: 0.6588 - val_accuracy: 0.9391 - val_loss: 0.5559 - learning_rate: 1.0000e-05
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8977 - loss: 0.6065 - val_accuracy: 0.9439 - val_loss: 0.5069 - learning_rate: 1.0000e-05
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9006 - loss: 0.5732 - val_accuracy: 0.9415 - val_loss: 0.4662 - learning_rate: 1.0000e-05
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9287 - loss: 0.5019 - val_accuracy: 0.9439 - val_loss: 0.4294 - learning_rate: 1.0000e-05
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9340 - loss: 0.4605 - val_accuracy: 0.9451 - val_loss: 0.3946 - learning_rate: 1.0000e-05
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9323 - loss: 0.4508 - val_accuracy: 0.9523 - val_loss: 0.3650 - learning_rate: 1.0000e-05
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9361 - loss: 0.4103 - val_accuracy: 0.9535 - val_loss: 0.3381 - learning_rate: 1.0000e-05
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9318 - loss: 0.3865 - val_accuracy: 0.9558 - val_loss: 0.3158 - learning_rate: 1.0000e-05
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9456 - loss: 0.3638 - val_accuracy: 0.9582 - val_loss: 0.2960 - learning_rate: 1.0000e-05
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9474 - loss: 0.3386 - val_accuracy: 0.9570 - val_loss: 0.2764 - learning_rate: 1.0000e-05
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.9397 - loss: 0.3307 - val_accuracy: 0.9594 - val_loss: 0.2591 - learning_rate: 1.0000e-05
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9540 - loss: 0.2954 - val_accuracy: 0.9606 - val_loss: 0.2464 - learning_rate: 1.0000e-05
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9552 - loss: 0.2968 - val_accuracy: 0.9594 - val_loss: 0.2331 - learning_rate: 1.0000e-05
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9576 - loss: 0.2686 - val_accuracy: 0.9642 - val_loss: 0.2189 - learning_rate: 1.0000e-05
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9594 - loss: 0.2610 - val_accuracy: 0.9630 - val_loss: 0.2099 - learning_rate: 1.0000e-05
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9553 - loss: 0.2450 - val_accuracy: 0.9642 - val_loss: 0.1984 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.
# 测试集准确率: 0.9628
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
#               precision    recall  f1-score   support
#
#         B007       0.89      0.99      0.94        96
#         B014       0.92      0.86      0.89        95
#         B021       0.99      0.80      0.88        95
#        IR007       0.99      1.00      0.99        95
#        IR014       0.98      0.98      0.98        95
#        IR021       0.91      1.00      0.95        95
#        OR007       0.97      1.00      0.98        95
#        OR014       1.00      1.00      1.00        95
#        OR021       0.96      0.96      0.96        96
#       Normal       1.00      1.00      1.00       190
#
#     accuracy                           0.96      1047
#    macro avg       0.96      0.96      0.96      1047
# weighted avg       0.96      0.96      0.96      1047

# %% [markdown]
# # 学习率太小，增加epoch从30到100

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置
# ===============================
file_paths = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]

labels = list(range(10))  # 10个类别

segment_length = 256   # 每个样本长度
test_size = 0.2        # 训练/测试划分比例
val_size = 0.2         # 验证集划分比例
overlap = 0.0          # 重叠率

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    X, y = load_and_segment_data(file_paths, labels, segment_length, overlap)

    # 划分
    X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=val_size, stratify=y_train_full, random_state=42)

    # 归一化 & 扩展维度
    mean, std = np.mean(X_train), np.std(X_train)
    X_train = ((X_train - mean) / std)[..., np.newaxis]
    X_val   = ((X_val   - mean) / std)[..., np.newaxis]
    X_test  = ((X_test  - mean) / std)[..., np.newaxis]

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape, y_val.shape)
print("测试集大小:", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    # 多头注意力
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    # 前馈网络
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # CNN 提取局部特征
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    # Transformer 层
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)

    # 分类头
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ✅ 发现已有预处理数据，直接加载
# 训练集大小: (3350, 256, 1) (3350,)
# 验证集大小: (838, 256, 1) (838,)
# 测试集大小: (1047, 256, 1) (1047,)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)    │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_6 (Conv1D)             │ (None, 256, 32)           │             256 │ input_layer_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_6               │ (None, 128, 32)           │               0 │ conv1d_6[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_7 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d_6[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_7               │ (None, 64, 64)            │               0 │ conv1d_7[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_10        │ (None, 64, 64)            │             128 │ max_pooling1d_7[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_5        │ (None, 64, 64)            │          16,640 │ layer_normalization_10[0]… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_9 (Add)                   │ (None, 64, 64)            │               0 │ max_pooling1d_7[0][0],     │
# │                               │                           │                 │ multi_head_attention_5[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_11        │ (None, 64, 64)            │             128 │ add_9[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 64, 64)            │           4,160 │ layer_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 64, 64)            │           4,160 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_10 (Add)                  │ (None, 64, 64)            │               0 │ add_9[0][0],               │
# │                               │                           │                 │ dense_11[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_12        │ (None, 64, 64)            │             128 │ add_10[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_6        │ (None, 64, 64)            │          16,640 │ layer_normalization_12[0]… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_11 (Add)                  │ (None, 64, 64)            │               0 │ add_10[0][0],              │
# │                               │                           │                 │ multi_head_attention_6[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_13        │ (None, 64, 64)            │             128 │ add_11[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 64, 64)            │           4,160 │ layer_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 64, 64)            │           4,160 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_12 (Add)                  │ (None, 64, 64)            │               0 │ add_11[0][0],              │
# │                               │                           │                 │ dense_13[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d_2    │ (None, 64)                │               0 │ add_12[0][0]               │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_9 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_14 (Dense)              │ (None, 10)                │             650 │ dropout_9[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.1876 - loss: 2.4337 - val_accuracy: 0.2530 - val_loss: 2.0336 - learning_rate: 1.0000e-05
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2789 - loss: 2.0999 - val_accuracy: 0.3735 - val_loss: 1.8504 - learning_rate: 1.0000e-05
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3162 - loss: 1.9347 - val_accuracy: 0.5215 - val_loss: 1.7147 - learning_rate: 1.0000e-05
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3763 - loss: 1.7851 - val_accuracy: 0.6289 - val_loss: 1.5972 - learning_rate: 1.0000e-05
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4608 - loss: 1.6204 - val_accuracy: 0.6408 - val_loss: 1.4831 - learning_rate: 1.0000e-05
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4704 - loss: 1.5470 - val_accuracy: 0.6838 - val_loss: 1.3744 - learning_rate: 1.0000e-05
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5523 - loss: 1.4078 - val_accuracy: 0.6850 - val_loss: 1.2665 - learning_rate: 1.0000e-05
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6115 - loss: 1.2940 - val_accuracy: 0.6945 - val_loss: 1.1637 - learning_rate: 1.0000e-05
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6309 - loss: 1.2071 - val_accuracy: 0.7124 - val_loss: 1.0690 - learning_rate: 1.0000e-05
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.6416 - loss: 1.1409 - val_accuracy: 0.7291 - val_loss: 0.9844 - learning_rate: 1.0000e-05
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6725 - loss: 1.0445 - val_accuracy: 0.7757 - val_loss: 0.9111 - learning_rate: 1.0000e-05
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7135 - loss: 0.9678 - val_accuracy: 0.8138 - val_loss: 0.8444 - learning_rate: 1.0000e-05
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7362 - loss: 0.9138 - val_accuracy: 0.8461 - val_loss: 0.7879 - learning_rate: 1.0000e-05
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7657 - loss: 0.8391 - val_accuracy: 0.8568 - val_loss: 0.7374 - learning_rate: 1.0000e-05
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7707 - loss: 0.8125 - val_accuracy: 0.8568 - val_loss: 0.6952 - learning_rate: 1.0000e-05
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7815 - loss: 0.7568 - val_accuracy: 0.8747 - val_loss: 0.6541 - learning_rate: 1.0000e-05
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8123 - loss: 0.7106 - val_accuracy: 0.8783 - val_loss: 0.6201 - learning_rate: 1.0000e-05
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8130 - loss: 0.6903 - val_accuracy: 0.8926 - val_loss: 0.5879 - learning_rate: 1.0000e-05
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8315 - loss: 0.6554 - val_accuracy: 0.8962 - val_loss: 0.5603 - learning_rate: 1.0000e-05
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8293 - loss: 0.6122 - val_accuracy: 0.9021 - val_loss: 0.5372 - learning_rate: 1.0000e-05
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8296 - loss: 0.6056 - val_accuracy: 0.9105 - val_loss: 0.5077 - learning_rate: 1.0000e-05
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8459 - loss: 0.5854 - val_accuracy: 0.9129 - val_loss: 0.4829 - learning_rate: 1.0000e-05
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8619 - loss: 0.5519 - val_accuracy: 0.9200 - val_loss: 0.4623 - learning_rate: 1.0000e-05
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8650 - loss: 0.5338 - val_accuracy: 0.9272 - val_loss: 0.4381 - learning_rate: 1.0000e-05
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8789 - loss: 0.4924 - val_accuracy: 0.9272 - val_loss: 0.4214 - learning_rate: 1.0000e-05
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8846 - loss: 0.4694 - val_accuracy: 0.9356 - val_loss: 0.3991 - learning_rate: 1.0000e-05
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8889 - loss: 0.4678 - val_accuracy: 0.9391 - val_loss: 0.3803 - learning_rate: 1.0000e-05
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8999 - loss: 0.4523 - val_accuracy: 0.9403 - val_loss: 0.3635 - learning_rate: 1.0000e-05
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9067 - loss: 0.3991 - val_accuracy: 0.9451 - val_loss: 0.3457 - learning_rate: 1.0000e-05
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9081 - loss: 0.4015 - val_accuracy: 0.9427 - val_loss: 0.3340 - learning_rate: 1.0000e-05
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9159 - loss: 0.3947 - val_accuracy: 0.9451 - val_loss: 0.3152 - learning_rate: 1.0000e-05
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9145 - loss: 0.3735 - val_accuracy: 0.9487 - val_loss: 0.3004 - learning_rate: 1.0000e-05
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9183 - loss: 0.3656 - val_accuracy: 0.9475 - val_loss: 0.2877 - learning_rate: 1.0000e-05
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9234 - loss: 0.3485 - val_accuracy: 0.9487 - val_loss: 0.2738 - learning_rate: 1.0000e-05
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9308 - loss: 0.3396 - val_accuracy: 0.9523 - val_loss: 0.2637 - learning_rate: 1.0000e-05
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9286 - loss: 0.3325 - val_accuracy: 0.9547 - val_loss: 0.2553 - learning_rate: 1.0000e-05
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9309 - loss: 0.3089 - val_accuracy: 0.9547 - val_loss: 0.2390 - learning_rate: 1.0000e-05
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9357 - loss: 0.2908 - val_accuracy: 0.9570 - val_loss: 0.2323 - learning_rate: 1.0000e-05
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9359 - loss: 0.2866 - val_accuracy: 0.9618 - val_loss: 0.2215 - learning_rate: 1.0000e-05
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9436 - loss: 0.2712 - val_accuracy: 0.9630 - val_loss: 0.2078 - learning_rate: 1.0000e-05
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9443 - loss: 0.2590 - val_accuracy: 0.9630 - val_loss: 0.2002 - learning_rate: 1.0000e-05
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9474 - loss: 0.2507 - val_accuracy: 0.9606 - val_loss: 0.1923 - learning_rate: 1.0000e-05
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9485 - loss: 0.2445 - val_accuracy: 0.9582 - val_loss: 0.1893 - learning_rate: 1.0000e-05
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9514 - loss: 0.2340 - val_accuracy: 0.9642 - val_loss: 0.1762 - learning_rate: 1.0000e-05
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9500 - loss: 0.2289 - val_accuracy: 0.9618 - val_loss: 0.1726 - learning_rate: 1.0000e-05
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9464 - loss: 0.2324 - val_accuracy: 0.9642 - val_loss: 0.1639 - learning_rate: 1.0000e-05
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9579 - loss: 0.1967 - val_accuracy: 0.9654 - val_loss: 0.1566 - learning_rate: 1.0000e-05
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9541 - loss: 0.1983 - val_accuracy: 0.9630 - val_loss: 0.1525 - learning_rate: 1.0000e-05
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9606 - loss: 0.1815 - val_accuracy: 0.9630 - val_loss: 0.1485 - learning_rate: 1.0000e-05
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9636 - loss: 0.1768 - val_accuracy: 0.9678 - val_loss: 0.1419 - learning_rate: 1.0000e-05
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9559 - loss: 0.1926 - val_accuracy: 0.9714 - val_loss: 0.1336 - learning_rate: 1.0000e-05
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9642 - loss: 0.1721 - val_accuracy: 0.9726 - val_loss: 0.1288 - learning_rate: 1.0000e-05
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9629 - loss: 0.1680 - val_accuracy: 0.9714 - val_loss: 0.1241 - learning_rate: 1.0000e-05
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.9705 - loss: 0.1513 - val_accuracy: 0.9714 - val_loss: 0.1196 - learning_rate: 1.0000e-05
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9592 - loss: 0.1661 - val_accuracy: 0.9737 - val_loss: 0.1161 - learning_rate: 1.0000e-05
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9663 - loss: 0.1544 - val_accuracy: 0.9714 - val_loss: 0.1140 - learning_rate: 1.0000e-05
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9722 - loss: 0.1393 - val_accuracy: 0.9749 - val_loss: 0.1099 - learning_rate: 1.0000e-05
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9703 - loss: 0.1467 - val_accuracy: 0.9773 - val_loss: 0.1047 - learning_rate: 1.0000e-05
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9710 - loss: 0.1384 - val_accuracy: 0.9797 - val_loss: 0.0998 - learning_rate: 1.0000e-05
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9719 - loss: 0.1382 - val_accuracy: 0.9821 - val_loss: 0.0962 - learning_rate: 1.0000e-05
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9701 - loss: 0.1309 - val_accuracy: 0.9833 - val_loss: 0.0951 - learning_rate: 1.0000e-05
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9780 - loss: 0.1204 - val_accuracy: 0.9821 - val_loss: 0.0925 - learning_rate: 1.0000e-05
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9680 - loss: 0.1266 - val_accuracy: 0.9845 - val_loss: 0.0881 - learning_rate: 1.0000e-05
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9787 - loss: 0.1140 - val_accuracy: 0.9857 - val_loss: 0.0847 - learning_rate: 1.0000e-05
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9757 - loss: 0.1127 - val_accuracy: 0.9833 - val_loss: 0.0835 - learning_rate: 1.0000e-05
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9736 - loss: 0.1180 - val_accuracy: 0.9845 - val_loss: 0.0788 - learning_rate: 1.0000e-05
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9752 - loss: 0.1055 - val_accuracy: 0.9881 - val_loss: 0.0757 - learning_rate: 1.0000e-05
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9806 - loss: 0.1035 - val_accuracy: 0.9869 - val_loss: 0.0744 - learning_rate: 1.0000e-05
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9765 - loss: 0.1056 - val_accuracy: 0.9893 - val_loss: 0.0716 - learning_rate: 1.0000e-05
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9821 - loss: 0.0971 - val_accuracy: 0.9833 - val_loss: 0.0742 - learning_rate: 1.0000e-05
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9759 - loss: 0.0999 - val_accuracy: 0.9857 - val_loss: 0.0674 - learning_rate: 1.0000e-05
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9847 - loss: 0.0890 - val_accuracy: 0.9893 - val_loss: 0.0664 - learning_rate: 1.0000e-05
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9841 - loss: 0.0865 - val_accuracy: 0.9905 - val_loss: 0.0639 - learning_rate: 1.0000e-05
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9830 - loss: 0.0846 - val_accuracy: 0.9905 - val_loss: 0.0604 - learning_rate: 1.0000e-05
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9876 - loss: 0.0812 - val_accuracy: 0.9905 - val_loss: 0.0622 - learning_rate: 1.0000e-05
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9864 - loss: 0.0740 - val_accuracy: 0.9916 - val_loss: 0.0566 - learning_rate: 1.0000e-05
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9884 - loss: 0.0796 - val_accuracy: 0.9905 - val_loss: 0.0552 - learning_rate: 1.0000e-05
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9858 - loss: 0.0739 - val_accuracy: 0.9905 - val_loss: 0.0538 - learning_rate: 1.0000e-05
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9869 - loss: 0.0750 - val_accuracy: 0.9916 - val_loss: 0.0544 - learning_rate: 1.0000e-05
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9848 - loss: 0.0729 - val_accuracy: 0.9893 - val_loss: 0.0525 - learning_rate: 1.0000e-05
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9912 - loss: 0.0691 - val_accuracy: 0.9893 - val_loss: 0.0498 - learning_rate: 1.0000e-05
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9908 - loss: 0.0649 - val_accuracy: 0.9905 - val_loss: 0.0480 - learning_rate: 1.0000e-05
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9893 - loss: 0.0639 - val_accuracy: 0.9905 - val_loss: 0.0463 - learning_rate: 1.0000e-05
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9851 - loss: 0.0724 - val_accuracy: 0.9905 - val_loss: 0.0455 - learning_rate: 1.0000e-05
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9863 - loss: 0.0662 - val_accuracy: 0.9893 - val_loss: 0.0453 - learning_rate: 1.0000e-05
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9891 - loss: 0.0625 - val_accuracy: 0.9916 - val_loss: 0.0445 - learning_rate: 1.0000e-05
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9886 - loss: 0.0590 - val_accuracy: 0.9916 - val_loss: 0.0429 - learning_rate: 1.0000e-05
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9925 - loss: 0.0537 - val_accuracy: 0.9916 - val_loss: 0.0412 - learning_rate: 1.0000e-05
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9891 - loss: 0.0550 - val_accuracy: 0.9916 - val_loss: 0.0403 - learning_rate: 1.0000e-05
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9903 - loss: 0.0559 - val_accuracy: 0.9928 - val_loss: 0.0393 - learning_rate: 1.0000e-05
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9874 - loss: 0.0568 - val_accuracy: 0.9928 - val_loss: 0.0388 - learning_rate: 1.0000e-05
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9931 - loss: 0.0473 - val_accuracy: 0.9928 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9940 - loss: 0.0480 - val_accuracy: 0.9905 - val_loss: 0.0370 - learning_rate: 1.0000e-05
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9941 - loss: 0.0466 - val_accuracy: 0.9905 - val_loss: 0.0379 - learning_rate: 1.0000e-05
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9945 - loss: 0.0475 - val_accuracy: 0.9916 - val_loss: 0.0368 - learning_rate: 1.0000e-05
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9922 - loss: 0.0482 - val_accuracy: 0.9940 - val_loss: 0.0369 - learning_rate: 1.0000e-05
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9922 - loss: 0.0462 - val_accuracy: 0.9916 - val_loss: 0.0341 - learning_rate: 1.0000e-05
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9936 - loss: 0.0411 - val_accuracy: 0.9916 - val_loss: 0.0326 - learning_rate: 1.0000e-05
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9955 - loss: 0.0391 - val_accuracy: 0.9940 - val_loss: 0.0335 - learning_rate: 1.0000e-05
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9919 - loss: 0.0441 - val_accuracy: 0.9928 - val_loss: 0.0325 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 100.
# 测试集准确率: 0.9914
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
#               precision    recall  f1-score   support
#
#         B007       0.98      0.99      0.98        96
#         B014       0.99      0.98      0.98        95
#         B021       0.97      0.97      0.97        95
#        IR007       1.00      1.00      1.00        95
#        IR014       0.98      0.98      0.98        95
#        IR021       1.00      1.00      1.00        95
#        OR007       1.00      1.00      1.00        95
#        OR014       1.00      1.00      1.00        95
#        OR021       0.99      0.99      0.99        96
#       Normal       1.00      1.00      1.00       190
#
#     accuracy                           0.99      1047
#    macro avg       0.99      0.99      0.99      1047
# weighted avg       0.99      0.99      0.99      1047
