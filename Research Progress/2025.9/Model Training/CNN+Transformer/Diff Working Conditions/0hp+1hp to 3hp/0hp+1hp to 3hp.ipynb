# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置（0hp+1hp用于训练/验证，3hp用于测试）
# ===============================
file_paths_0hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_0.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_0.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_0.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_0.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_0.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_0.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_0.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_0.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_0.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_0.mat"                     # Normal
]
file_paths_1hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_1.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_1.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_1.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_1.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_1.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_1.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_1.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_1.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_1.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_1.mat"                     # Normal
]
file_paths_3hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_3.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_3.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_3.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_3.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_3.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_3.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_3.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_3.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_3.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_3.mat"                     # Normal
]
labels = list(range(10))

segment_length = 256
val_size  = 0.2       # 从 (0hp+1hp) 划一部分做验证
overlap   = 0.0

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer\Diff Working Conditions\0hp+1hp to 3hp"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
    # 训练/验证数据：0hp + 1hp
    X0, y0 = load_and_segment_data(file_paths_0hp, labels, segment_length, overlap)
    X1, y1 = load_and_segment_data(file_paths_1hp, labels, segment_length, overlap)
    X_trainval = np.vstack([X0, X1])
    y_trainval = np.hstack([y0, y1])

    # 测试数据：3hp
    X3, y3 = load_and_segment_data(file_paths_3hp, labels, segment_length, overlap)

    # 划分 train/val
    X_train_full, X_val, y_train_full, y_val = train_test_split(
        X_trainval, y_trainval, test_size=val_size, stratify=y_trainval, random_state=42
    )

    # 归一化：用训练集的统计量
    mean, std = np.mean(X_train_full), np.std(X_train_full)
    X_train = ((X_train_full - mean) / std)[..., np.newaxis]
    X_val   = ((X_val       - mean) / std)[..., np.newaxis]
    X_test  = ((X3          - mean) / std)[..., np.newaxis]   # 注意：3hp 用相同的均值方差

    y_train = y_train_full
    y_test  = y3

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape,   y_val.shape)
print("跨工况测试集大小(3hp):", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])
    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ⚙️ 重新从 .mat 文件生成数据
# 训练集大小: (9125, 256, 1) (9125,)
# 验证集大小: (2282, 256, 1) (2282,)
# 跨工况测试集大小(3hp): (6186, 256, 1) (6186,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 256, 32)           │             256 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d (MaxPooling1D)  │ (None, 128, 32)           │               0 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_1               │ (None, 64, 64)            │               0 │ conv1d_1[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 64, 64)            │             128 │ max_pooling1d_1[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 64, 64)            │          16,640 │ layer_normalization[0][0], │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 64, 64)            │               0 │ max_pooling1d_1[0][0],     │
# │                               │                           │                 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 64, 64)            │             128 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64, 64)            │           4,160 │ layer_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 64, 64)            │           4,160 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 64, 64)            │               0 │ add[0][0], dense_1[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 64, 64)            │             128 │ add_1[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 64, 64)            │          16,640 │ layer_normalization_2[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_2[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 64, 64)            │               0 │ add_1[0][0],               │
# │                               │                           │                 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 64, 64)            │             128 │ add_2[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64, 64)            │           4,160 │ layer_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 64, 64)            │           4,160 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 64, 64)            │               0 │ add_2[0][0], dense_3[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 64)                │               0 │ add_3[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 10)                │             650 │ dropout_2[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.6090 - loss: 1.1638 - val_accuracy: 0.9592 - val_loss: 0.1122 - learning_rate: 0.0010
# Epoch 2/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9382 - loss: 0.1644 - val_accuracy: 0.9663 - val_loss: 0.0908 - learning_rate: 0.0010
# Epoch 3/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9660 - loss: 0.0936 - val_accuracy: 0.9755 - val_loss: 0.0651 - learning_rate: 0.0010
# Epoch 4/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9711 - loss: 0.0904 - val_accuracy: 0.9794 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 5/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9882 - loss: 0.0380 - val_accuracy: 0.9908 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 6/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9843 - loss: 0.0438 - val_accuracy: 0.9759 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 7/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9812 - loss: 0.0498 - val_accuracy: 0.9917 - val_loss: 0.0178 - learning_rate: 0.0010
# Epoch 8/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9971 - loss: 0.0119 - val_accuracy: 0.9912 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 9/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9784 - loss: 0.0760 - val_accuracy: 0.9934 - val_loss: 0.0310 - learning_rate: 0.0010
# Epoch 10/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9884 - loss: 0.0386 - val_accuracy: 0.9899 - val_loss: 0.0286 - learning_rate: 0.0010
# Epoch 11/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9937 - loss: 0.0187 - val_accuracy: 0.9869 - val_loss: 0.0429 - learning_rate: 0.0010
# Epoch 12/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9945 - loss: 0.0150 - val_accuracy: 0.9961 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 13/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9948 - loss: 0.0140 - val_accuracy: 0.9917 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 14/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9951 - loss: 0.0135 - val_accuracy: 0.9965 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 15/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9873 - loss: 0.0374 - val_accuracy: 0.9917 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 16/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9962 - loss: 0.0136 - val_accuracy: 0.9961 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 17/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9938 - loss: 0.0190 - val_accuracy: 0.9917 - val_loss: 0.0181 - learning_rate: 0.0010
# Epoch 18/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9958 - loss: 0.0112 - val_accuracy: 0.9956 - val_loss: 0.0183 - learning_rate: 0.0010
# Epoch 19/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9970 - loss: 0.0095 - val_accuracy: 0.9982 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 20/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9961 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 21/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9992 - loss: 0.0017 - val_accuracy: 0.9987 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 22/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9974 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 23/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9813 - loss: 0.0678 - val_accuracy: 0.9961 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 24/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9957 - loss: 0.0121 - val_accuracy: 0.9873 - val_loss: 0.0422 - learning_rate: 0.0010
# Epoch 25/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9928 - loss: 0.0261 - val_accuracy: 0.9969 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 26/30
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9990 - loss: 0.0034
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9952 - val_loss: 0.0193 - learning_rate: 0.0010
# Epoch 27/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9993 - loss: 0.0050 - val_accuracy: 0.9978 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Epoch 28/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.9999 - loss: 5.8277e-04 - val_accuracy: 0.9969 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 29/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 4.4789e-04 - val_accuracy: 0.9978 - val_loss: 0.0051 - learning_rate: 5.0000e-04
# Epoch 30/30
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 1.0000 - loss: 3.0085e-04 - val_accuracy: 0.9978 - val_loss: 0.0038 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 27.
# 测试集准确率: 0.8320
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
#               precision    recall  f1-score   support
#
#         B007       1.00      0.87      0.93       474
#         B014       0.40      0.93      0.55       477
#         B021       0.95      0.04      0.08       477
#        IR007       0.70      1.00      0.82       480
#        IR014       0.00      0.00      0.00       475
#        IR021       1.00      1.00      1.00       476
#        OR007       1.00      1.00      1.00       478
#        OR014       1.00      1.00      1.00       476
#        OR021       0.80      0.98      0.88       476
#       Normal       0.98      1.00      0.99      1897
#
#     accuracy                           0.83      6186
#    macro avg       0.78      0.78      0.73      6186
# weighted avg       0.83      0.83      0.79      6186
