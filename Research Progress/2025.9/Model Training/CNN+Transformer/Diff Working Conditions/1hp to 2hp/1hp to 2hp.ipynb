# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 或 'Microsoft YaHei'
matplotlib.rcParams['axes.unicode_minus'] = False   # 解决负号显示问题

# ===============================
# 1. 文件路径配置（1hp用于训练/验证，2hp用于测试）
# ===============================
file_paths_1hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_1.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_1.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_1.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_1.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_1.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_1.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_1.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_1.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_1.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_1.mat"                     # Normal
]
file_paths_2hp = [
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/B007_2.mat",   # B007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/B014_2.mat",   # B014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/B021_2.mat",   # B021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/IR007_2.mat",  # IR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/IR014_2.mat",  # IR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/IR021_2.mat",  # IR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.007/OR007@6_2.mat",# OR007
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.014/OR014@6_2.mat",# OR014
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/12k Drive End Bearing Fault Data/0.021/OR021@6_2.mat",# OR021
    r"D:/HuaweiMoveData/Users/hps_h/Desktop/CWRU/Normal Baseline Data/Normal_2.mat"                     # Normal
]
labels = list(range(10))

segment_length = 256
test_size = 0.2       # 只用于 1hp 内部 train/val 划分之前的 train/test？——这次不用它来切 2hp
val_size  = 0.2       # 从 1hp 的训练部分再划验证
overlap   = 0.0

# 保存目录
save_dir = r"D:\study\code\Model Training\CNN+Transformer\Diff Working Conditions\1hp to 2hp"

# ===============================
# 2. 数据预处理函数
# ===============================
def load_and_segment_data(file_paths, labels, segment_length, overlap):
    X, y = [], []
    step = int(segment_length * (1 - overlap))  # 步长
    for file, label in zip(file_paths, labels):
        mat_dict = loadmat(file)
        key = [k for k in mat_dict.keys() if "DE_time" in k][0]   # 驱动端数据
        signal = mat_dict[key].squeeze()

        # 带重叠切片
        segments = []
        for start in range(0, len(signal) - segment_length + 1, step):
            seg = signal[start:start + segment_length]
            segments.append(seg)
        segments = np.array(segments)

        X.append(segments)
        y.extend([label] * len(segments))

    X = np.vstack(X)
    y = np.array(y)
    return X, y

# ===============================
# 3. 数据加载
# ===============================
save_files = [os.path.join(save_dir, f) for f in ["X_train.npy","y_train.npy","X_val.npy","y_val.npy","X_test.npy","y_test.npy"]]

if all(os.path.exists(f) for f in save_files):
    print("✅ 发现已有预处理数据，直接加载")
    X_train = np.load(os.path.join(save_dir, "X_train.npy"))
    y_train = np.load(os.path.join(save_dir, "y_train.npy"))
    X_val   = np.load(os.path.join(save_dir, "X_val.npy"))
    y_val   = np.load(os.path.join(save_dir, "y_val.npy"))
    X_test  = np.load(os.path.join(save_dir, "X_test.npy"))
    y_test  = np.load(os.path.join(save_dir, "y_test.npy"))
else:
    print("⚙️ 重新从 .mat 文件生成数据")
# ===============================
# 2. 生成数据（1hp -> 供 train/val；2hp -> 供 test）
# ===============================
    X1, y1 = load_and_segment_data(file_paths_1hp, labels, segment_length, overlap)  # 源域
    X2, y2 = load_and_segment_data(file_paths_2hp, labels, segment_length, overlap)  # 目标域（仅测试）
    
    # 0hp 内部分：先划出临时train_full/val临时（保持你的习惯，也可直接 train/val）
    X_train_full, X_val, y_train_full, y_val = train_test_split(
        X1, y1, test_size=val_size, stratify=y1, random_state=42
    )
    
    # 归一化：**只用 0hp 的训练统计量**（避免泄露目标域信息）
    mean, std = np.mean(X_train_full), np.std(X_train_full)
    X_train = ((X_train_full - mean) / std)[..., np.newaxis]
    X_val   = ((X_val       - mean) / std)[..., np.newaxis]
    X_test  = ((X2          - mean) / std)[..., np.newaxis]   # 注意：2hp 仅用 0hp 的均值方差做标准化
    
    y_train = y_train_full
    y_test  = y2

    # 保存
    os.makedirs(save_dir, exist_ok=True)
    np.save(os.path.join(save_dir, "X_train.npy"), X_train)
    np.save(os.path.join(save_dir, "y_train.npy"), y_train)
    np.save(os.path.join(save_dir, "X_val.npy"), X_val)
    np.save(os.path.join(save_dir, "y_val.npy"), y_val)
    np.save(os.path.join(save_dir, "X_test.npy"), X_test)
    np.save(os.path.join(save_dir, "y_test.npy"), y_test)


print("训练集大小:", X_train.shape, y_train.shape)
print("验证集大小:", X_val.shape,   y_val.shape)
print("跨工况测试集大小(2hp):", X_test.shape, y_test.shape)

# ===============================
# 4. 定义 CNN+Transformer 模型
# ===============================
def transformer_block(x, head_size, num_heads, ff_dim, dropout=0):
    # 多头注意力
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    attn_output = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x_norm, x_norm)
    x = layers.Add()([x, attn_output])

    # 前馈网络
    x_norm = layers.LayerNormalization(epsilon=1e-6)(x)
    ff_output = layers.Dense(ff_dim, activation="relu")(x_norm)
    ff_output = layers.Dense(x.shape[-1])(ff_output)
    x = layers.Add()([x, ff_output])

    return x

def build_cnn_transformer(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)

    # CNN 提取局部特征
    x = layers.Conv1D(32, 7, padding="same", activation="relu")(inputs)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    # Transformer 层
    for _ in range(2):
        x = transformer_block(x, head_size=32, num_heads=2, ff_dim=64, dropout=0.1)

    # 分类头
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return models.Model(inputs, outputs)

num_classes = len(np.unique(y_train))
model = build_cnn_transformer(input_shape=(segment_length,1), num_classes=num_classes)
model.summary()

# ===============================
# 5. 训练模型
# ===============================
model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

callbacks = [
    ReduceLROnPlateau(factor=0.5, patience=5, verbose=1),
    EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=30,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)

# ===============================
# 6. 结果评估
# ===============================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"测试集准确率: {test_acc:.4f}")

# 学习曲线
plt.figure(figsize=(10,4))
plt.plot(history.history["accuracy"], label="训练集")
plt.plot(history.history["val_accuracy"], label="验证集")
plt.xlabel("Epochs"); plt.ylabel("Accuracy"); plt.legend(); plt.title("学习曲线")
plt.show()

# 混淆矩阵及分类报告
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)
class_names = ["B007","B014","B021","IR007","IR014","IR021","OR007","OR014","OR021","Normal"]

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("预测值"); plt.ylabel("真实值"); plt.title("混淆矩阵")
plt.show()

print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# ⚙️ 重新从 .mat 文件生成数据
# 训练集大小: (4937, 256, 1) (4937,)
# 验证集大小: (1235, 256, 1) (1235,)
# 跨工况测试集大小(2hp): (6174, 256, 1) (6174,)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 256, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 256, 32)           │             256 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_4               │ (None, 128, 32)           │               0 │ conv1d_4[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_5 (Conv1D)             │ (None, 128, 64)           │          10,304 │ max_pooling1d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling1d_5               │ (None, 64, 64)            │               0 │ conv1d_5[0][0]             │
# │ (MaxPooling1D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_8         │ (None, 64, 64)            │             128 │ max_pooling1d_5[0][0]      │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_4        │ (None, 64, 64)            │          16,640 │ layer_normalization_8[0][… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_8[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_8 (Add)                   │ (None, 64, 64)            │               0 │ max_pooling1d_5[0][0],     │
# │                               │                           │                 │ multi_head_attention_4[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_9         │ (None, 64, 64)            │             128 │ add_8[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 64, 64)            │           4,160 │ layer_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 64, 64)            │           4,160 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_9 (Add)                   │ (None, 64, 64)            │               0 │ add_8[0][0],               │
# │                               │                           │                 │ dense_11[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_10        │ (None, 64, 64)            │             128 │ add_9[0][0]                │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_5        │ (None, 64, 64)            │          16,640 │ layer_normalization_10[0]… │
# │ (MultiHeadAttention)          │                           │                 │ layer_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_10 (Add)                  │ (None, 64, 64)            │               0 │ add_9[0][0],               │
# │                               │                           │                 │ multi_head_attention_5[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_11        │ (None, 64, 64)            │             128 │ add_10[0][0]               │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 64, 64)            │           4,160 │ layer_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 64, 64)            │           4,160 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_11 (Add)                  │ (None, 64, 64)            │               0 │ add_10[0][0],              │
# │                               │                           │                 │ dense_13[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d_2    │ (None, 64)                │               0 │ add_11[0][0]               │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_8 (Dropout)           │ (None, 64)                │               0 │ global_average_pooling1d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_14 (Dense)              │ (None, 10)                │             650 │ dropout_8[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 61,642 (240.79 KB)
#  Trainable params: 61,642 (240.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.5317 - loss: 1.3554 - val_accuracy: 0.8858 - val_loss: 0.2722 - learning_rate: 0.0010
# Epoch 2/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9003 - loss: 0.2846 - val_accuracy: 0.9344 - val_loss: 0.1848 - learning_rate: 0.0010
# Epoch 3/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9469 - loss: 0.1559 - val_accuracy: 0.9684 - val_loss: 0.0865 - learning_rate: 0.0010
# Epoch 4/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.9664 - loss: 0.0947 - val_accuracy: 0.9603 - val_loss: 0.0946 - learning_rate: 0.0010
# Epoch 5/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.9770 - loss: 0.0719 - val_accuracy: 0.9676 - val_loss: 0.0909 - learning_rate: 0.0010
# Epoch 6/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9827 - loss: 0.0560 - val_accuracy: 0.9676 - val_loss: 0.0737 - learning_rate: 0.0010
# Epoch 7/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9773 - loss: 0.0568 - val_accuracy: 0.9749 - val_loss: 0.0576 - learning_rate: 0.0010
# Epoch 8/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9795 - loss: 0.0564 - val_accuracy: 0.9733 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 9/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9766 - loss: 0.0649 - val_accuracy: 0.9579 - val_loss: 0.1137 - learning_rate: 0.0010
# Epoch 10/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9599 - loss: 0.1194 - val_accuracy: 0.9798 - val_loss: 0.0531 - learning_rate: 0.0010
# Epoch 11/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9877 - loss: 0.0336 - val_accuracy: 0.9838 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 12/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9854 - loss: 0.0369 - val_accuracy: 0.9838 - val_loss: 0.0499 - learning_rate: 0.0010
# Epoch 13/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.9934 - loss: 0.0213 - val_accuracy: 0.9895 - val_loss: 0.0369 - learning_rate: 0.0010
# Epoch 14/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9891 - loss: 0.0343 - val_accuracy: 0.9895 - val_loss: 0.0339 - learning_rate: 0.0010
# Epoch 15/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.9937 - loss: 0.0183 - val_accuracy: 0.9911 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 16/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9955 - loss: 0.0107 - val_accuracy: 0.9968 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 17/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9846 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 18/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9511 - loss: 0.1894 - val_accuracy: 0.9895 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 19/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9918 - loss: 0.0240 - val_accuracy: 0.9968 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 20/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 57ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 0.9992 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 21/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.9968 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 22/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9984 - loss: 0.0054 - val_accuracy: 0.9798 - val_loss: 0.0758 - learning_rate: 0.0010
# Epoch 23/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9937 - loss: 0.0294 - val_accuracy: 0.9968 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 24/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 1.0000 - loss: 6.8527e-04 - val_accuracy: 0.9984 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 25/30
# 77/78 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9998 - loss: 0.0012
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9992 - val_loss: 0.0099 - learning_rate: 0.0010
# Epoch 26/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9984 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 27/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 1.0000 - loss: 3.2121e-04 - val_accuracy: 0.9984 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 28/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 1.0000 - loss: 4.4015e-04 - val_accuracy: 0.9992 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 29/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 1.0000 - loss: 3.9436e-04 - val_accuracy: 0.9992 - val_loss: 0.0023 - learning_rate: 5.0000e-04
# Epoch 30/30
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 1.0000 - loss: 3.3802e-04 - val_accuracy: 0.9992 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 30.
# 测试集准确率: 0.9948
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
#               precision    recall  f1-score   support
#
#         B007       1.00      1.00      1.00       474
#         B014       1.00      0.99      0.99       476
#         B021       0.99      0.96      0.97       477
#        IR007       1.00      1.00      1.00       477
#        IR014       1.00      0.99      0.99       475
#        IR021       0.99      1.00      1.00       475
#        OR007       1.00      1.00      1.00       474
#        OR014       0.96      1.00      0.98       475
#        OR021       1.00      1.00      1.00       477
#       Normal       1.00      1.00      1.00      1894
#
#     accuracy                           0.99      6174
#    macro avg       0.99      0.99      0.99      6174
# weighted avg       0.99      0.99      0.99      6174
